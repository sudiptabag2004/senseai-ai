# %%
import json

# %%
roadmap_path = '../app/javascript_roadmap.json'

# %%
roadmap = json.load(open(roadmap_path, 'r'))

# %%
for topic in roadmap:
    for bloom_level in roadmap[topic]['learning_outcomes']
# Out:
# {'Basics - Data Types and Variables': {'learning_outcomes': {'Remember': ['Identify the basic data types in JavaScript (string, number, boolean, null, undefined, object, and symbol)',
#     'List the rules for naming variables in JavaScript',
#     'Recall the purpose of variables in programming'],
#    'Understand': ['Describe the differences between the various data types in JavaScript',
#     'Explain the concept of variable declaration, initialization, and assignment',
#     'Paraphrase the importance of using appropriate data types for different tasks in programming'],
#    'Apply': ['Use variables to store and manipulate data in a JavaScript program',
#     'Demonstrate the correct usage of different data types in a JavaScript program',
#     'Apply the rules for naming variables when creating new variables in a JavaScript program'],
#    'Analyze': ['Break down a given JavaScript code snippet to identify the data types and variables used',
# ...
